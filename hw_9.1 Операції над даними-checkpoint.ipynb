# %% [markdown]
# # # 1 Cтворіть змінні a, b, c та d, задайте їм значення відповідно 101, 210, 111, 402, та обчисліть з допомогою Python наступний вираз:
# (a+b)∗cd
# Важливо: тут ми маємо обчислити значення саме з використанням змінних, а не просто чисел, як би ми робили у калькуряторі. Змінні потрібні аби за бажання ми могли змінити їх значення та не переписувати код обчислення виразу, бо він буде працювати для різних значень змінних.

# %%
a = 101
b = 210
c = 111
d = 402

# %%
result = ((a + b) * c) / d
print(round(result, 2))
# Out:
# 85.87

# %% [markdown]
# # # 2 Якою буде остача від ділення числа 11283 на 89? Обчисліть з допомогою Python

# %%
a=11283%89
print(a)
# Out:
# 69

# %% [markdown]
# # # 3 Скільки цілих разів поміститься число 89 в 11283? (Або що те саме: який буде результат цілочисельного ділення 11283 на 89?)

# %%
g=11283//89
print(g)
# Out:
# 126

# %% [markdown]
# # # 4 Запишіть у змінну name ваше імʼя.

# %%
name = "Alena"

# %% [markdown]
# # # 5 Запишіть у змінну surname ваше прізвище

# %%
surname = "Zaporozets"

# %% [markdown]
# # # 6 Сконкатенуйте імʼя та прізвище в одну фразу через пробіл. Запишіть результат у нову змінну name_surname та виведіть результат на екран.

# %%
name_surname = name + " " + surname
print(name_surname)
# Out:
# Alena Zaporozets

# %% [markdown]
# # # 7 Зробіть усі літери змінної name_surname заглавними використовуючи метод рядків в Python:Очікувана відповідь (тільки з вашими даними): 'HANNA PYLIEVA'

# %%
print(name_surname.upper())
# Out:
# ALENA ZAPOROZETS

# %% [markdown]
# # # 8 Виведіть третю літеру вашого name_surname. Тут уважно, треба саме третя літера. Згадайте, з якого значення починається індексування значень в Python.Очікувана відповідь (тільки з вашими даними): 'n'

# %%
print(name_surname[2])
# Out:
# e

# %% [markdown]
# # # 9 Виведіть першу та останню літеру вашого прізвища.Очікувана відповідь (тільки з вашими даними): ('P', 'a')

# %%
print((surname[0], surname[2]))
# Out:
# ('Z', 'p')

# %% [markdown]
# # # 10 Виведіть довжину вашого прізвища.Очікувана відповідь (тільки з вашими даними): 7

# %%
len(name_surname)
# Out:
# 16

# %% [markdown]
# # #11 Виведіть кількість літер a у столиці Мадагаскару Antananarivo. Важливо врахувати всі літери, як великі, так і маленькі.

# %%
sity = "Antananarivo"
litera_a = sity.lower().count('a')
print(litera_a)
# Out:
# 4

# %% [markdown]
# # #12 Створіть рядок my_string зі значенням: "The quick brown fox jumps over the lazy dog!!!".
# Перевірте, чи починається рядок my_string з "The" і чи закінчується він "dog!". Виведіть результати на екран.

# %%
my_string = "The quick brown fox jumps over the lazy dog!!!"
starts_with_The = my_string.startswith("The")
ends_with_dog = my_string.endswith("dog!")
print(starts_with_The)
print(ends_with_dog)
# Out:
# True
# False

# %% [markdown]
# # #13 Розділіть рядок my_string на список окремих слів, а потім з'єднайте всі слова через нижнє підкреслювання. Виведіть результат на екран.Очікуваний результат: The_quick_brown_fox_jumps_over_the_lazy_dog!!!

# %%
sentence = my_string.split(" ")
print(sentence)
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog!!!']

# %%
result = "_".join(sentence)
print(result)
# Out:
# The_quick_brown_fox_jumps_over_the_lazy_dog!!!
